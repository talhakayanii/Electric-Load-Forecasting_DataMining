# %%
import pandas as pd
import numpy as np
from kneed import KneeLocator
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage
import warnings

import gc  
warnings.filterwarnings('ignore')

def load_and_sample_data(file_path='merged_weather_demand_final.csv', sample_size=5000, random_state=42):
    """
    Load the dataset and take a representative sample with a smaller default size.
    """
    print(f"Loading data from {file_path}...")

    # Loading the full dataset
    df = pd.read_csv(file_path)
    print(f"Full dataset shape: {df.shape}")

    # Taking a sample to reduce memory
    df_sample = df.sample(n=min(sample_size, len(df)), random_state=random_state)

    print(f"Sample dataset shape: {df_sample.shape}")
    return df_sample

def prepare_features_for_clustering(df, features_to_use=None):
    """
    Prepare specific features for clustering.
    If features_to_use is None, it will use a default set of features.
    """
    # Default features for clustering 
    if features_to_use is None:
        features_to_use = [
            'Demand (MW)',       # Main target variable
               
            'Hour',
            
            'Weekend'
                      
        ]  

   
    available_features = [f for f in features_to_use if f in df.columns]

    if len(available_features) < len(features_to_use):
        missing = set(features_to_use) - set(available_features)
        print(f"Warning: Some requested features are not available: {missing}")

    # Selecting only the specified features
    df_features = df[available_features].copy()

    
    missing_values = df_features.isnull().sum()
    if missing_values.sum() > 0:
        print("Warning: Missing values detected:")
        print(missing_values[missing_values > 0])
        print("Filling missing values with median...")
        df_features = df_features.fillna(df_features.median())

    print(f"Features selected for clustering: {available_features}")
    return df_features

def normalize_features(df_features):
    """
    Normalize/scale features for clustering.
    """
    print("Normalizing features...")

    # Initialize the scaler
    scaler = StandardScaler()

    # Fit and transform the data
    df_scaled = pd.DataFrame(
        scaler.fit_transform(df_features),
        columns=df_features.columns,
        index=df_features.index
    )

    return df_scaled

def reduce_dimensions(df_scaled, n_components_pca=2):
    """
    Apply PCA and t-SNE for dimensionality reduction, with optimized memory usage.
    """
    print("Performing dimensionality reduction...")

    # PCA
    pca = PCA(n_components=n_components_pca)
    pca_result = pca.fit_transform(df_scaled)

    # Create a DataFrame for PCA results
    pca_df = pd.DataFrame(
        data=pca_result,
        columns=[f'PCA{i+1}' for i in range(n_components_pca)],
        index=df_scaled.index
    )

    # Calculate explained variance
    explained_variance = pca.explained_variance_ratio_
    print(f"PCA explained variance: {explained_variance}")
    print(f"Total variance explained: {sum(explained_variance):.2f}")

    # t-SNE
    print("Applying t-SNE on a subset of data to save memory...")
    # Subsample for t-SNE to reduce memory usage
    max_tsne_samples = min(1000, len(df_scaled))  # Reduced max samples

    df_tsne = df_scaled.sample(max_tsne_samples, random_state=42)

    # Applying t-SNE with reduced perplexity
    tsne = TSNE(
        n_components=2,
        random_state=42,
        perplexity=min(30, len(df_tsne) // 5),
        n_iter=1000  # Reduced iterations
    )
    tsne_result = tsne.fit_transform(df_tsne)

    # Creating a DataFrame for t-SNE results
    tsne_df = pd.DataFrame(
        data=tsne_result,
        columns=['tSNE1', 'tSNE2'],
        index=df_tsne.index
    )

    # Clean up to free memory
    del tsne
    gc.collect()

    return pca_df, tsne_df, explained_variance

def kmeans_clustering(df_scaled, max_k=8):  # Reduced max_k
    """
    Perform K-Means clustering and determine the optimal number of clusters.
    """
    print("Performing K-Means clustering...")

    # Determine optimal K using elbow method and silhouette scores
    inertia = []
    silhouette_scores = []

    for k in range(2, max_k + 1):
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        labels = kmeans.fit_predict(df_scaled)
        inertia.append(kmeans.inertia_)
        silhouette_scores.append(silhouette_score(df_scaled, labels))
        print(f"K={k}: Inertia={kmeans.inertia_:.2f}, Silhouette Score={silhouette_scores[-1]:.4f}")

        # Clean up memory after each iteration
        del kmeans
        gc.collect()

    # Plotting elbow curve
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(range(2, max_k + 1), inertia, marker='o')
    plt.title('Elbow Method')
    plt.xlabel('Number of clusters')
    plt.ylabel('Inertia')
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(range(2, max_k + 1), silhouette_scores, marker='o')
    plt.title('Silhouette Score Method')
    plt.xlabel('Number of clusters')
    plt.ylabel('Silhouette Score')
    plt.grid(True)

    plt.tight_layout()
    plt.savefig('kmeans_elbow.png', dpi=100)  
    plt.close()  # Close to free memory

    # Get optimal K based on silhouette score
    optimal_k = silhouette_scores.index(max(silhouette_scores)) + 2
    print(f"Optimal number of clusters based on silhouette score: {optimal_k}")

    # Apply K-Means with optimal K
    kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(df_scaled)

    return labels, optimal_k

def dbscan_clustering(df_scaled):
    """
    Improved DBSCAN clustering with optimized parameter selection.
    """
    print("Performing DBSCAN clustering with optimized parameters...")
    
    # Calculate k-distance plot to determine optimal eps
    def calculate_k_distance(df, k=5, sample_size=1000):
        """Calculate k-distance for a sample of points to help determine eps."""
        from sklearn.neighbors import NearestNeighbors
        
        if len(df) > sample_size:
            df_sample = df.sample(sample_size, random_state=42)
        else:
            df_sample = df
            
        nbrs = NearestNeighbors(n_neighbors=k+1).fit(df_sample)
        distances, _ = nbrs.kneighbors(df_sample)
        k_distances = np.sort(distances[:, k])[::-1]
        return k_distances
    
    k_distances = calculate_k_distance(df_scaled, k=5)
    
    
    plt.figure(figsize=(10, 6))
    plt.plot(np.arange(len(k_distances)), k_distances, 'b-')
    plt.title('k-Distance Graph (k=5)')
    plt.xlabel('Points sorted by distance to 5th nearest neighbor')
    plt.ylabel('5th nearest neighbor distance')
    plt.grid(True)
    plt.savefig('dbscan_k_distance_plot.png', dpi=100)
    plt.close()
    
    # Automatically determine eps from the k-distance plot
    from kneed import KneeLocator
    
    try:
        kneedle = KneeLocator(np.arange(len(k_distances)), k_distances, curve='convex', direction='decreasing')
        eps_candidate = kneedle.knee_y
        print(f"Automatically detected eps candidate: {eps_candidate:.4f}")
    except:
        eps_candidate = np.percentile(k_distances, 90)
        print(f"Using fallback eps value: {eps_candidate:.4f}")
    
    # Set min_samples based on dimensionality
    min_samples = 2 * df_scaled.shape[1]
    print(f"Using min_samples: {min_samples}")
    
    # Try multiple parameter combinations
    eps_values = np.linspace(eps_candidate * 0.8, eps_candidate * 1.2, 3)
    min_samples_values = [min_samples, min_samples + 5, min_samples + 10]
    
    best_score = -1
    best_params = None
    best_labels = None
    
    for eps in eps_values:
        for min_samples in min_samples_values:
            dbscan = DBSCAN(eps=eps, min_samples=min_samples)
            labels = dbscan.fit_predict(df_scaled)
            
            unique_labels = set(labels)
            n_clusters = len(unique_labels) - (1 if -1 in unique_labels else 0)
            n_noise = list(labels).count(-1)
            noise_ratio = n_noise / len(labels)
            
            if 2 <= n_clusters <= 10 and noise_ratio < 0.3:
                non_noise_mask = labels != -1
                if sum(non_noise_mask) > 1:
                    sil_score = silhouette_score(df_scaled[non_noise_mask], labels[non_noise_mask])
                    print(f"eps={eps:.3f}, min_samples={min_samples}: clusters={n_clusters}, "
                          f"noise={noise_ratio:.2%}, silhouette={sil_score:.4f}")
                    
                    # Score combines silhouette and low noise preference
                    score = sil_score * (1 - noise_ratio)
                    if score > best_score:
                        best_score = score
                        best_params = (eps, min_samples)
                        best_labels = labels
    
    if best_params:
        print(f"\nBest DBSCAN parameters: eps={best_params[0]:.3f}, min_samples={best_params[1]}")
        print(f"Number of clusters: {len(set(best_labels)) - (1 if -1 in best_labels else 0)}")
        print(f"Noise points: {list(best_labels).count(-1)}/{len(best_labels)} "
              f"({list(best_labels).count(-1)/len(best_labels):.2%})")
        return best_labels
    else:
        print("\nNo optimal parameters found, using fallback parameters")
        dbscan = DBSCAN(eps=eps_candidate, min_samples=min_samples)
        labels = dbscan.fit_predict(df_scaled)
        return labels

def hierarchical_clustering(df_scaled, sample_size=500):
    """
    Performing hierarchical clustering and plot dendrogram with smaller sample.
    """
    print("Performing hierarchical clustering...")

    # Take a smaller sample for hierarchical clustering to save memory
    sample_size = min(sample_size, len(df_scaled))
    sample_indices = np.random.choice(len(df_scaled), size=sample_size, replace=False)
    df_sample = df_scaled.iloc[sample_indices]

    # Compute the linkage matrix
    Z = linkage(df_sample, method='ward')

    # Plot dendrogram
    plt.figure(figsize=(12, 7))
    plt.title('Hierarchical Clustering Dendrogram')
    plt.xlabel('Data points')
    plt.ylabel('Distance')

    dendrogram(
        Z,
        truncate_mode='lastp',
        p=30,
        leaf_rotation=90.,
        leaf_font_size=12.,
        show_contracted=True
    )

    plt.axhline(y=15, c='k', linestyle='--', alpha=0.5)
    plt.savefig('hierarchical_dendrogram.png', dpi=100)
    plt.close()

    
    n_clusters = 4

    
    print(f"Applying Agglomerative Clustering with {n_clusters} clusters to full dataset...")
    agg = AgglomerativeClustering(n_clusters=n_clusters)
    labels = agg.fit_predict(df_scaled)

    # Clean up
    del Z, agg
    gc.collect()

    return labels, n_clusters

def visualize_clusters(df_original, pca_df, tsne_df, labels, method_name):
    """
    Visualize clusters in PCA and t-SNE space with improved consistency.
    """
    print(f"Visualizing {method_name} clusters...")

    # Create a color map for clusters
    unique_labels = np.unique(labels)
    
    if -1 in unique_labels:  # DBSCAN case
        n_clusters = len(unique_labels) - 1
        colors = plt.cm.tab20(np.linspace(0, 1, max(n_clusters, 1)))
        color_map = {}
        label_map = {-1: 'Noise'}
        cluster_idx = 0
        for label in unique_labels:
            if label != -1:
                color_map[label] = colors[cluster_idx]
                label_map[label] = f'Cluster {label+1}'
                cluster_idx += 1
        color_map[-1] = (0.7, 0.7, 0.7, 1)
    else:
        n_clusters = len(unique_labels)
        colors = plt.cm.tab20(np.linspace(0, 1, n_clusters))
        color_map = {i: colors[i] for i in range(n_clusters)}
        label_map = {i: f'Cluster {i+1}' for i in range(n_clusters)}

    # Create visualization data
    index_to_label = {idx: lbl for idx, lbl in zip(df_original.index[:len(labels)], labels)}
    
    # PCA visualization
    pca_viz_data = []
    for i, idx in enumerate(pca_df.index):
        if idx in index_to_label:
            pca_viz_data.append({
                'PCA1': pca_df.iloc[i, 0],
                'PCA2': pca_df.iloc[i, 1],
                'Cluster': label_map[index_to_label[idx]],
                'label_raw': index_to_label[idx]
            })
    pca_for_viz = pd.DataFrame(pca_viz_data)

    # t-SNE visualization
    tsne_for_viz = None
    if len(tsne_df) > 0:
        tsne_viz_data = []
        for i, idx in enumerate(tsne_df.index):
            if idx in index_to_label:
                tsne_viz_data.append({
                    'tSNE1': tsne_df.iloc[i, 0],
                    'tSNE2': tsne_df.iloc[i, 1],
                    'Cluster': label_map[index_to_label[idx]],
                    'label_raw': index_to_label[idx]
                })
        if tsne_viz_data:
            tsne_for_viz = pd.DataFrame(tsne_viz_data)

    # Plot PCA and t-SNE results
    plt.figure(figsize=(12, 10))
    
    # PCA plot
    plt.subplot(2, 1, 1)
    for cluster_name in sorted(pca_for_viz['Cluster'].unique()):
        mask = pca_for_viz['Cluster'] == cluster_name
        if mask.any():
            raw_label = pca_for_viz.loc[mask, 'label_raw'].iloc[0]
            color = color_map.get(raw_label, (0, 0, 0, 1))
            plt.scatter(
                pca_for_viz.loc[mask, 'PCA1'],
                pca_for_viz.loc[mask, 'PCA2'],
                s=30, alpha=0.7,
                label=cluster_name,
                color=color
            )
    plt.title(f'{method_name}: Clusters in PCA Space')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.legend()
    plt.grid(True)

    # t-SNE plot if available
    if tsne_for_viz is not None and len(tsne_for_viz) > 0:
        plt.subplot(2, 1, 2)
        for cluster_name in sorted(tsne_for_viz['Cluster'].unique()):
            mask = tsne_for_viz['Cluster'] == cluster_name
            if mask.any():
                raw_label = tsne_for_viz.loc[mask, 'label_raw'].iloc[0]
                color = color_map.get(raw_label, (0, 0, 0, 1))
                plt.scatter(
                    tsne_for_viz.loc[mask, 'tSNE1'],
                    tsne_for_viz.loc[mask, 'tSNE2'],
                    s=30, alpha=0.7,
                    label=cluster_name,
                    color=color
                )
        plt.title(f'{method_name}: Clusters in t-SNE Space')
        plt.xlabel('t-SNE Component 1')
        plt.ylabel('t-SNE Component 2')
        plt.legend()
        plt.grid(True)

    plt.tight_layout()
    plt.savefig(f'{method_name}_clusters.png', dpi=100)
    plt.close()

    # Adding cluster labels to original data
    df_with_clusters = df_original.copy()
    df_with_clusters['Cluster'] = pd.Series([label_map[l] for l in labels], index=df_original.index[:len(labels)])

    # Visualizing key features by cluster
    key_features = ['Demand (MW)', 'Temperature (F)', 'Hour']
    key_features = [f for f in key_features if f in df_with_clusters.columns]

    if key_features:
        plt.figure(figsize=(15, 5 * len(key_features)))
        for i, feature in enumerate(key_features):
            plt.subplot(len(key_features), 1, i+1)
            sns.boxplot(x='Cluster', y=feature, data=df_with_clusters)
            plt.title(f'{feature} Distribution by Cluster')
            plt.grid(True)

        plt.tight_layout()
        plt.savefig(f'{method_name}_features.png', dpi=100)
        plt.close()

    return df_with_clusters

def interpret_clusters(df_with_clusters):
    """
    Improved cluster interpretation with better demand categorization.
    """
    print("Interpreting clusters...")

    features_to_interpret = [
        'Demand (MW)', 'Temperature (F)', 'Humidity', 
        'Hour', 'Weekday', 'Month'
    ]
    features_to_interpret = [f for f in features_to_interpret if f in df_with_clusters.columns]

    cluster_stats = df_with_clusters.groupby('Cluster')[features_to_interpret].agg(['mean', 'median', 'std'])
    print("\nCluster Statistics:")
    print(cluster_stats)

    cluster_interpretations = {}
    overall_avg_demand = df_with_clusters['Demand (MW)'].mean()

    for cluster in df_with_clusters['Cluster'].unique():
        cluster_data = df_with_clusters[df_with_clusters['Cluster'] == cluster]
        interpretation = f"Cluster {cluster}:\n"
        interpretation += f"- Size: {len(cluster_data)} points ({len(cluster_data)/len(df_with_clusters):.1%})\n"

        # Improved demand interpretation
        if 'Demand (MW)' in cluster_data.columns:
            avg_demand = cluster_data['Demand (MW)'].mean()
            if avg_demand > overall_avg_demand * 1.5:
                interpretation += "- Peak demand periods\n"
            elif avg_demand > overall_avg_demand * 1.2:
                interpretation += "- High demand periods\n"
            elif avg_demand < overall_avg_demand * 0.7:
                interpretation += "- Low demand periods\n"
            elif avg_demand < overall_avg_demand * 0.9:
                interpretation += "- Below average demand\n"
            else:
                interpretation += "- Typical demand periods\n"

        # Temperature interpretation
        if 'Temperature (F)' in cluster_data.columns:
            avg_temp = cluster_data['Temperature (F)'].mean()
            if avg_temp > 80:
                interpretation += "- Hot weather conditions\n"
            elif avg_temp > 65:
                interpretation += "- Warm weather conditions\n"
            elif avg_temp < 45:
                interpretation += "- Cold weather conditions\n"
            else:
                interpretation += "- Moderate temperatures\n"

        # Time interpretation
        if 'Hour' in cluster_data.columns:
            hour_counts = cluster_data['Hour'].value_counts(normalize=True)
            peak_hours = hour_counts[hour_counts > 0.1].index.tolist()
            if peak_hours:
                interpretation += f"- Peak hours: {sorted(peak_hours)}\n"

        # Day type interpretation
        if 'Weekday' in cluster_data.columns:
            weekday_ratio = cluster_data[cluster_data['Weekday'] < 5].shape[0] / len(cluster_data)
            if weekday_ratio > 0.7:
                interpretation += "- Primarily weekdays\n"
            elif weekday_ratio < 0.3:
                interpretation += "- Primarily weekends\n"
            else:
                interpretation += "- Mixed weekdays/weekends\n"

        cluster_interpretations[cluster] = interpretation

    print("\nCluster Interpretations:")
    for cluster, interpretation in cluster_interpretations.items():
        print(interpretation)
        print("---")

    return cluster_interpretations

def run_clustering_analysis(file_path='merged_weather_demand_final.csv', sample_size=5000, features_to_use=None):
    """
    Run the entire clustering analysis pipeline.
    """
    try:
        # 1. Loading and sampling data
        df_sample = load_and_sample_data(file_path, sample_size)

        # 2. Selecting and preparing features
        df_features = prepare_features_for_clustering(df_sample, features_to_use)

        # 3. Normalizing features
        df_scaled = normalize_features(df_features)

        # 4. Dimensionality reduction
        pca_df, tsne_df, explained_variance = reduce_dimensions(df_scaled)

        # 5-7. Performing clustering
        kmeans_labels, optimal_k = kmeans_clustering(df_scaled)
        dbscan_labels = dbscan_clustering(df_scaled)
        hierarchical_labels, n_hierarchical_clusters = hierarchical_clustering(df_scaled)

        # 8. Visualizing clusters
        kmeans_with_clusters = visualize_clusters(df_sample, pca_df, tsne_df, kmeans_labels, 'K-Means')
        dbscan_with_clusters = visualize_clusters(df_sample, pca_df, tsne_df, dbscan_labels, 'DBSCAN')
        hierarchical_with_clusters = visualize_clusters(df_sample, pca_df, tsne_df, hierarchical_labels, 'Hierarchical')

        # 9. Interpretation of clusters
        kmeans_interpretations = interpret_clusters(kmeans_with_clusters)
        dbscan_interpretations = interpret_clusters(dbscan_with_clusters)
        hierarchical_interpretations = interpret_clusters(hierarchical_with_clusters)

        # 10. Evaluating clustering
        def calculate_silhouette(labels, data):
            if -1 in labels:  # DBSCAN case
                non_noise = labels != -1
                if sum(non_noise) > 1:
                    return silhouette_score(data[non_noise], labels[non_noise])
                return "N/A (too much noise)"
            return silhouette_score(data, labels)

        kmeans_silhouette = silhouette_score(df_scaled, kmeans_labels)
        dbscan_silhouette = calculate_silhouette(dbscan_labels, df_scaled)
        hierarchical_silhouette = silhouette_score(df_scaled, hierarchical_labels)

        print("\nClustering Evaluation:")
        print(f"K-Means Silhouette Score: {kmeans_silhouette:.4f}")
        print(f"DBSCAN Silhouette Score: {dbscan_silhouette}")
        print(f"Hierarchical Silhouette Score: {hierarchical_silhouette:.4f}")

        print("\nClustering analysis complete!")
        print("Visualizations saved as PNG files.")

        return {
            'kmeans': {
                'labels': kmeans_labels,
                'optimal_k': optimal_k,
                'silhouette': kmeans_silhouette,
                'df_with_clusters': kmeans_with_clusters,
                'interpretations': kmeans_interpretations
            },
            'dbscan': {
                'labels': dbscan_labels,
                'silhouette': dbscan_silhouette,
                'df_with_clusters': dbscan_with_clusters,
                'interpretations': dbscan_interpretations
            },
            'hierarchical': {
                'labels': hierarchical_labels,
                'n_clusters': n_hierarchical_clusters,
                'silhouette': hierarchical_silhouette,
                'df_with_clusters': hierarchical_with_clusters,
                'interpretations': hierarchical_interpretations
            }
        }
    except MemoryError as e:
        print("\n*** MEMORY ERROR ***")
        print("Try reducing sample_size or using fewer features")
        print(f"Error: {e}")
        return None
    except Exception as e:
        print(f"\n*** ERROR: {type(e).__name__} ***")
        print(f"Details: {e}")
        return None

if __name__ == "__main__":
    #  features for clustering
    clustering_features = [
        'Demand (MW)',
        
        'Hour',
       
        'Weekend'
        
    ]

    
    results = run_clustering_analysis(
        file_path='merged_weather_demand_final.csv',
        sample_size=16000,
        features_to_use=clustering_features
    )
# Out:
# Loading data from merged_weather_demand_final.csv...
# Full dataset shape: (165192, 21)
# Sample dataset shape: (3000, 21)
# Warning: Some requested features are not available: {'MonthWeekday'}
# Features selected for clustering: ['Demand (MW)', 'Hour', 'Weekend']
# Normalizing features...
# Performing dimensionality reduction...
# PCA explained variance: [0.3454848  0.33229899]
# Total variance explained: 0.68
# Applying t-SNE on a subset of data to save memory...
# Performing K-Means clustering...
# K=2: Inertia=5996.37, Silhouette Score=0.4023
# K=3: Inertia=4265.49, Silhouette Score=0.4261
# K=4: Inertia=2967.05, Silhouette Score=0.4204
# K=5: Inertia=2375.27, Silhouette Score=0.4379
# K=6: Inertia=1884.38, Silhouette Score=0.4661
# K=7: Inertia=1573.56, Silhouette Score=0.4625
# K=8: Inertia=1327.84, Silhouette Score=0.4191
# Optimal number of clusters based on silhouette score: 6
# Performing DBSCAN clustering...
# eps=0.040, min_samples=5: clusters=159, noise=46.73%, silhouette=0.7974
# eps=0.060, min_samples=5: clusters=174, noise=34.60%, silhouette=0.6762
# Best DBSCAN parameters: eps=0.040, min_samples=5
# Number of clusters: 159
# Noise points: 1402/3000 (46.73%)
# Performing hierarchical clustering...
# Applying Agglomerative Clustering with 4 clusters to full dataset...
# Visualizing K-Means clusters...
# Visualizing DBSCAN clusters...
# Visualizing Hierarchical clusters...
# Interpreting clusters...
#
# Cluster Statistics:
#             Demand (MW)                       Temperature (F)          \
#                    mean   median          std            mean  median
# Cluster
# Cluster 1   2452.823656   1942.0  1964.034349       64.614286  64.500
# Cluster 2  10273.549161  10461.0  1622.834031       62.473094  60.600
# Cluster 3   1884.210731   1416.0  1632.281609       61.255746  60.750
# Cluster 4   2191.006273   1787.0  1783.858572       60.894462  61.300
# Cluster 5   9710.192771   9917.5  1575.724862       62.558554  61.265
# Cluster 6   2335.906368   1831.0  1774.513474       65.514847  65.690
#
#                       Humidity                  Wind Speed (mph)  ...  \
#                  std      mean median       std             mean  ...
# Cluster                                                           ...
# Cluster 1  15.870851  0.629341   0.65  0.217521         6.570000  ...
# Cluster 2  11.750409  0.637134   0.69  0.200850         4.677074  ...
# Cluster 3  16.406651  0.685910   0.74  0.220598         5.711731  ...
# Cluster 4  16.485238  0.705102   0.76  0.209782         5.571149  ...
# Cluster 5  11.168059  0.677380   0.73  0.197681         4.622892  ...
# Cluster 6  16.452714  0.596735   0.61  0.213974         6.073544  ...
#
#                           Hour                    Weekday                   \
#                 std       mean median       std      mean median       std
# Cluster
# Cluster 1  3.570613  17.580681   18.0  3.405526  1.970362    2.0  1.396306
# Cluster 2  2.477673  10.496403   11.0  6.637279  1.916067    2.0  1.441205
# Cluster 3  3.222480   5.346269    5.0  3.485570  5.495522    5.0  0.500728
# Cluster 4  3.306256   5.679904    6.0  3.455545  2.123947    2.0  1.398895
# Cluster 5  2.661688  11.036145   11.0  6.270558  5.421687    5.0  0.495323
# Cluster 6  3.096807  17.552941   18.0  3.478568  5.497059    5.0  0.500728
#
#               Month
#                mean median       std
# Cluster
# Cluster 1  6.495060    7.0  3.571519
# Cluster 2  6.256595    6.0  3.679969
# Cluster 3  6.582090    7.0  3.635113
# Cluster 4  6.335740    7.0  3.598415
# Cluster 5  6.614458    7.0  3.615895
# Cluster 6  6.594118    7.0  3.460689
#
# [6 rows x 21 columns]
#
# Cluster Interpretations:
# Cluster Cluster 4:
# - Size: 831 data points (27.7% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings, nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 6:
# - Size: 340 data points (11.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons, evenings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 2:
# - Size: 417 data points (13.9% of data)
# - Very high electricity demand
# - Moderate temperatures
# - No strong time-of-day pattern
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 1:
# - Size: 911 data points (30.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons, evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 5:
# - Size: 166 data points (5.5% of data)
# - Very high electricity demand
# - Moderate temperatures
# - No strong time-of-day pattern
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 3:
# - Size: 335 data points (11.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings, nights
# - Strongly associated with weekends
#
# ---
# Interpreting clusters...
#
# Cluster Statistics:
#              Demand (MW)                      Temperature (F)         \
#                     mean  median          std            mean median
# Cluster
# Cluster 1      93.900000    92.0    38.658968       60.811000  63.86
# Cluster 10   4014.800000  3999.0    39.701385       49.734000  45.84
# Cluster 100    73.111111    58.0    17.919573       59.762222  60.63
# Cluster 101  9652.642857  9629.5   105.152554       72.716429  75.73
# Cluster 102  9510.888889  9513.0   135.640559       56.557778  53.94
# ...                  ...     ...          ...             ...    ...
# Cluster 96     84.400000    92.0    32.638277       73.387333  73.52
# Cluster 97     77.428571    92.0    18.173764       60.728571  61.91
# Cluster 98   3745.833333  3736.0   117.803933       45.060000  45.55
# Cluster 99    859.777778   885.0    91.295917       75.885556  77.61
# Noise        5829.130170  4880.5  3573.181888       62.231679  61.44
#
#                         Humidity                  Wind Speed (mph)  ...  \
#                    std      mean median       std             mean  ...
# Cluster                                                             ...
# Cluster 1    12.686484  0.770000  0.790  0.151380         5.443000  ...
# Cluster 10   13.242556  0.826000  0.840  0.077974         4.354000  ...
# Cluster 100   7.343383  0.843333  0.930  0.187483         7.791111  ...
# Cluster 101  12.967488  0.443571  0.505  0.179483         7.537143  ...
# Cluster 102   6.266416  0.653333  0.730  0.220114         3.515556  ...
# ...                ...       ...    ...       ...              ...  ...
# Cluster 96   16.083864  0.564000  0.520  0.196607         8.958000  ...
# Cluster 97   15.738663  0.822857  0.790  0.130348         8.008571  ...
# Cluster 98    6.285739  0.788333  0.795  0.145522         3.711667  ...
# Cluster 99   19.610356  0.294444  0.330  0.101503         3.976667  ...
# Noise        14.934676  0.669576  0.700  0.202663         5.530895  ...
#
#                             Hour                    Weekday                   \
#                   std       mean median       std      mean median       std
# Cluster
# Cluster 1    3.831030   8.000000    8.0  0.000000  2.400000    3.0  1.353358
# Cluster 10   2.852986   4.000000    4.0  0.000000  1.200000    1.0  1.303840
# Cluster 100  2.480511   7.000000    7.0  0.000000  5.000000    5.0  0.000000
# Cluster 101  1.848062   0.000000    0.0  0.000000  1.714286    1.0  1.380131
# Cluster 102  1.704634   6.000000    6.0  0.000000  1.444444    2.0  1.236033
# ...               ...        ...    ...       ...       ...    ...       ...
# Cluster 96   4.055834  22.000000   22.0  0.000000  1.533333    1.0  0.990430
# Cluster 97   5.168541   9.000000    9.0  0.000000  5.285714    5.0  0.487950
# Cluster 98   1.763479   5.000000    5.0  0.000000  1.166667    1.0  0.983192
# Cluster 99   1.488296   3.000000    3.0  0.000000  5.666667    6.0  0.500000
# Noise        3.086972  11.704708   12.0  6.846942  3.490014    4.0  2.063302
#
#                 Month
#                  mean median       std
# Cluster
# Cluster 1    6.950000    8.0  3.471311
# Cluster 10   6.000000    4.0  5.147815
# Cluster 100  6.555556    4.0  4.585605
# Cluster 101  4.000000    4.0  2.236068
# Cluster 102  3.888889    4.0  3.018462
# ...               ...    ...       ...
# Cluster 96   6.400000    7.0  3.887710
# Cluster 97   6.428571    7.0  4.825527
# Cluster 98   7.833333   10.0  4.167333
# Cluster 99   8.666667    8.0  3.041381
# Noise        6.453638    7.0  3.517620
#
# [160 rows x 21 columns]
#
# Cluster Interpretations:
# Cluster Noise:
# - Size: 1402 data points (46.7% of data)
# - Very high electricity demand
# - Moderate temperatures
# - No strong time-of-day pattern
#
# ---
# Cluster Cluster 1:
# - Size: 20 data points (0.7% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 2:
# - Size: 8 data points (0.3% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 3:
# - Size: 15 data points (0.5% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 4:
# - Size: 17 data points (0.6% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 5:
# - Size: 6 data points (0.2% of data)
# - Very high electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
# - Predominantly in May
#
# ---
# Cluster Cluster 6:
# - Size: 7 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 7:
# - Size: 18 data points (0.6% of data)
# - Very high electricity demand
# - Cool temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 8:
# - Size: 15 data points (0.5% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 9:
# - Size: 13 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 10:
# - Size: 5 data points (0.2% of data)
# - High electricity demand
# - Cool temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 11:
# - Size: 14 data points (0.5% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 12:
# - Size: 11 data points (0.4% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 13:
# - Size: 17 data points (0.6% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 14:
# - Size: 9 data points (0.3% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during nights
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 15:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 16:
# - Size: 24 data points (0.8% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 17:
# - Size: 24 data points (0.8% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 18:
# - Size: 13 data points (0.4% of data)
# - Average electricity demand
# - Cool temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 19:
# - Size: 5 data points (0.2% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 20:
# - Size: 5 data points (0.2% of data)
# - Very high electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 21:
# - Size: 18 data points (0.6% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 22:
# - Size: 19 data points (0.6% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 23:
# - Size: 20 data points (0.7% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 24:
# - Size: 14 data points (0.5% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 25:
# - Size: 15 data points (0.5% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 26:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 27:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekends
# - Predominantly in August
#
# ---
# Cluster Cluster 28:
# - Size: 6 data points (0.2% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 29:
# - Size: 15 data points (0.5% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 30:
# - Size: 21 data points (0.7% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 31:
# - Size: 5 data points (0.2% of data)
# - High electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 32:
# - Size: 18 data points (0.6% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 33:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekends
# - Predominantly in March
#
# ---
# Cluster Cluster 34:
# - Size: 15 data points (0.5% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 35:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 98:
# - Size: 6 data points (0.2% of data)
# - Average electricity demand
# - Cool temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 36:
# - Size: 20 data points (0.7% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 37:
# - Size: 7 data points (0.2% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 38:
# - Size: 15 data points (0.5% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 39:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 40:
# - Size: 10 data points (0.3% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 41:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 42:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 43:
# - Size: 6 data points (0.2% of data)
# - Average electricity demand
# - Cool temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 44:
# - Size: 9 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 45:
# - Size: 12 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 46:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 47:
# - Size: 16 data points (0.5% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 48:
# - Size: 14 data points (0.5% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 49:
# - Size: 13 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 50:
# - Size: 19 data points (0.6% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 51:
# - Size: 12 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 52:
# - Size: 10 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 53:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 54:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 55:
# - Size: 26 data points (0.9% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 56:
# - Size: 12 data points (0.4% of data)
# - Very high electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 121:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 76:
# - Size: 5 data points (0.2% of data)
# - High electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 57:
# - Size: 13 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 58:
# - Size: 14 data points (0.5% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 59:
# - Size: 17 data points (0.6% of data)
# - Very high electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 60:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 61:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
# - Predominantly in March
#
# ---
# Cluster Cluster 62:
# - Size: 15 data points (0.5% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 63:
# - Size: 6 data points (0.2% of data)
# - Very high electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
# - Predominantly in October
#
# ---
# Cluster Cluster 64:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 65:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 146:
# - Size: 5 data points (0.2% of data)
# - Very high electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
# - Predominantly in April
#
# ---
# Cluster Cluster 66:
# - Size: 6 data points (0.2% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 67:
# - Size: 18 data points (0.6% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 143:
# - Size: 9 data points (0.3% of data)
# - Very high electricity demand
# - Cool temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 68:
# - Size: 21 data points (0.7% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 69:
# - Size: 12 data points (0.4% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 93:
# - Size: 7 data points (0.2% of data)
# - Very high electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
# - Predominantly in January
#
# ---
# Cluster Cluster 70:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during nights
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 71:
# - Size: 12 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 72:
# - Size: 10 data points (0.3% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 73:
# - Size: 14 data points (0.5% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 74:
# - Size: 7 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
# - Predominantly in March
#
# ---
# Cluster Cluster 75:
# - Size: 13 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 136:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 77:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekends
# - Predominantly in December
#
# ---
# Cluster Cluster 90:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 78:
# - Size: 7 data points (0.2% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during nights
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 79:
# - Size: 16 data points (0.5% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 80:
# - Size: 13 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 81:
# - Size: 9 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 82:
# - Size: 6 data points (0.2% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 83:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
# - Predominantly in December
#
# ---
# Cluster Cluster 84:
# - Size: 16 data points (0.5% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 139:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 85:
# - Size: 7 data points (0.2% of data)
# - Average electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 86:
# - Size: 10 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 87:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 88:
# - Size: 16 data points (0.5% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 104:
# - Size: 8 data points (0.3% of data)
# - Very high electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 89:
# - Size: 7 data points (0.2% of data)
# - Very low electricity demand
# - Hot temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
# - Predominantly in July
#
# ---
# Cluster Cluster 91:
# - Size: 11 data points (0.4% of data)
# - High electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 122:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 92:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 94:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 95:
# - Size: 19 data points (0.6% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 96:
# - Size: 15 data points (0.5% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 97:
# - Size: 7 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 140:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
# - Predominantly in September
#
# ---
# Cluster Cluster 99:
# - Size: 9 data points (0.3% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during nights
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 100:
# - Size: 9 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 101:
# - Size: 7 data points (0.2% of data)
# - Very high electricity demand
# - Warm temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
# - Predominantly in April
#
# ---
# Cluster Cluster 102:
# - Size: 9 data points (0.3% of data)
# - Very high electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 119:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 103:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 155:
# - Size: 5 data points (0.2% of data)
# - Very high electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 105:
# - Size: 7 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 106:
# - Size: 15 data points (0.5% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 107:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 108:
# - Size: 9 data points (0.3% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
# - Predominantly in February
#
# ---
# Cluster Cluster 109:
# - Size: 14 data points (0.5% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 110:
# - Size: 10 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 111:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 112:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during nights
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 113:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
# - Predominantly in November
#
# ---
# Cluster Cluster 148:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 114:
# - Size: 9 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 115:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 153:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 116:
# - Size: 7 data points (0.2% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 117:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 118:
# - Size: 14 data points (0.5% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 120:
# - Size: 12 data points (0.4% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 123:
# - Size: 12 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 145:
# - Size: 6 data points (0.2% of data)
# - Very high electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 124:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 125:
# - Size: 5 data points (0.2% of data)
# - Very high electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 126:
# - Size: 10 data points (0.3% of data)
# - High electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 154:
# - Size: 7 data points (0.2% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 159:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 156:
# - Size: 5 data points (0.2% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 152:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 127:
# - Size: 6 data points (0.2% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
# - Predominantly in September
#
# ---
# Cluster Cluster 128:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 129:
# - Size: 9 data points (0.3% of data)
# - Very high electricity demand
# - Cool temperatures
# - Predominantly during afternoons
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 130:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 131:
# - Size: 5 data points (0.2% of data)
# - Very high electricity demand
# - Cool temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 132:
# - Size: 10 data points (0.3% of data)
# - Very low electricity demand
# - Cool temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
# - Predominantly in January
#
# ---
# Cluster Cluster 133:
# - Size: 11 data points (0.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 134:
# - Size: 7 data points (0.2% of data)
# - High electricity demand
# - Cold temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 135:
# - Size: 6 data points (0.2% of data)
# - High electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 137:
# - Size: 6 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 138:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 157:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 141:
# - Size: 6 data points (0.2% of data)
# - Very high electricity demand
# - Moderate temperatures
# - Predominantly during nights
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 142:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 144:
# - Size: 5 data points (0.2% of data)
# - High electricity demand
# - Cool temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 158:
# - Size: 5 data points (0.2% of data)
# - Very high electricity demand
# - Cool temperatures
# - Predominantly during mornings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 147:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Warm temperatures
# - Predominantly during evenings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 149:
# - Size: 8 data points (0.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during evenings
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 151:
# - Size: 5 data points (0.2% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 150:
# - Size: 6 data points (0.2% of data)
# - Average electricity demand
# - Cool temperatures
# - Predominantly during mornings
# - Strongly associated with weekends
#
# ---
# Interpreting clusters...
#
# Cluster Statistics:
#             Demand (MW)                       Temperature (F)          \
#                    mean   median          std            mean  median
# Cluster
# Cluster 1   2269.227450   1689.0  1898.299166       63.403199  62.520
# Cluster 2   2457.457126   1871.0  2133.922736       63.966465  64.180
# Cluster 3  10591.659274  10526.0  1189.394687       61.920373  60.365
# Cluster 4   2622.347818   2090.0  2019.520717       61.041933  60.690
#
#                       Humidity                  Wind Speed (mph)  ...  \
#                  std      mean median       std             mean  ...
# Cluster                                                           ...
# Cluster 1  16.478479  0.646977  0.680  0.221004         5.873789  ...
# Cluster 2  15.693443  0.660059  0.700  0.218980         6.250964  ...
# Cluster 3  10.907898  0.624577  0.670  0.201032         4.572994  ...
# Cluster 4  17.052133  0.687178  0.725  0.208434         5.686069  ...
#
#                           Hour                    Weekday                   \
#                 std       mean median       std      mean median       std
# Cluster
# Cluster 1  3.153936  11.487106   12.0  6.957174  5.491404    5.0  0.500285
# Cluster 2  3.561068  15.791282   16.0  4.527232  2.010897    2.0  1.403154
# Cluster 3  2.481846  10.546371   10.0  6.791399  2.931452    3.0  2.020936
# Cluster 4  3.230066   4.267537    4.0  2.966624  2.092985    2.0  1.397769
#
#               Month
#                mean median       std
# Cluster
# Cluster 1  6.547278    7.0  3.531563
# Cluster 2  6.450126    7.0  3.542560
# Cluster 3  6.445565    6.5  3.753121
# Cluster 4  6.319739    7.0  3.620776
#
# [4 rows x 21 columns]
#
# Cluster Interpretations:
# Cluster Cluster 2:
# - Size: 1193 data points (39.8% of data)
# - Very low electricity demand
# - Moderate temperatures
# - No strong time-of-day pattern
# - Strongly associated with weekdays
#
# ---
# Cluster Cluster 1:
# - Size: 698 data points (23.3% of data)
# - Very low electricity demand
# - Moderate temperatures
# - No strong time-of-day pattern
# - Strongly associated with weekends
#
# ---
# Cluster Cluster 3:
# - Size: 496 data points (16.5% of data)
# - Very high electricity demand
# - Moderate temperatures
# - No strong time-of-day pattern
#
# ---
# Cluster Cluster 4:
# - Size: 613 data points (20.4% of data)
# - Very low electricity demand
# - Moderate temperatures
# - Predominantly during mornings, nights
# - Strongly associated with weekdays
#
# ---
#
# Clustering Evaluation:
# K-Means Silhouette Score: 0.4661
# DBSCAN Silhouette Score: 0.7973531351015629
# Hierarchical Silhouette Score: 0.3786
#
# Clustering analysis complete!
#
# Note: All visualizations have been saved as PNG files.
